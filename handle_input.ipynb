# %%
import json
import numpy as np

# %%
data_str = open('sample1.json', 'r').read()

# %%
input_dict = json.loads(data_str)

# %%
input_dict
# Out:
# {'mean_radius': [25.22,
#   10.48,
#   18.81,
#   12.63,
#   14.34,
#   12.58,
#   10.48,
#   12.72,
#   11.14,
#   19.21,
#   13.74,
#   17.02,
#   14.25,
#   12.68,
#   12.89,
#   14.59],
#  'mean_texture': [24.91,
#   14.98,
#   19.98,
#   20.76,
#   13.47,
#   18.4,
#   19.86,
#   17.67,
#   14.07,
#   18.57,
#   17.91,
#   23.98,
#   21.72,
#   23.84,
#   13.12,
#   22.68],
#  'mean_perimeter': [171.5,
#   67.49,
#   120.9,
#   82.15,
#   92.51,
#   79.83,
#   66.72,
#   80.98,
#   71.24,
#   125.5,
#   88.12,
#   112.8,
#   93.63,
#   82.69,
#   81.89,
#   96.39],
#  'mean_area': [1878.0,
#   333.6,
#   1102.0,
#   480.4,
#   641.2,
#   489.0,
#   337.7,
#   501.3,
#   384.6,
#   1152.0,
#   585.0,
#   899.3,
#   633.0,
#   499.0,
#   515.9,
#   657.1],
#  'mean_smoothness': [0.1063,
#   0.09816,
#   0.08923,
#   0.09933,
#   0.09906,
#   0.08393,
#   0.107,
#   0.07896,
#   0.07274,
#   0.1053,
#   0.07944,
#   0.1197,
#   0.09823,
#   0.1122,
#   0.06955,
#   0.08473],
# ...

# %%
# input_dict, as is , già si dovrebbe poter mandare in input al metodo onnx_predict (TO CHECK)
