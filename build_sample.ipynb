# %% [markdown]
# ### The notebook builds a sample JSON from the original dataset

# %%
import numpy as np
import pandas as pd
import json
from sklearn.datasets import load_breast_cancer

# %%
# prepare the dataset for test

# we take the dataset from Sklearn
data = load_breast_cancer(as_frame=True)

# I prefer working with Dataframe
orig_df = data.frame

# we must rename columns, to remove spaces in names
# otherwise we get problems with ONNX

# substitute all spaces with _
dict_columns = {}

for col in orig_df.columns:
    dict_columns[col] = col.replace(" ", "_")

orig_df = orig_df.rename(columns=dict_columns)

# %%
orig_df.head(10)
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
# 6        18.25         19.98          119.60     1040.0          0.09463
# 7        13.71         20.83           90.20      577.9          0.11890
# 8        13.00         21.82           87.50      519.8          0.12730
# 9        12.46         24.04           83.97      475.9          0.11860
#
#    mean_compactness  mean_concavity  mean_concave_points  mean_symmetry  \
# 0           0.27760         0.30010              0.14710         0.2419
# 1           0.07864         0.08690              0.07017         0.1812
# 2           0.15990         0.19740              0.12790         0.2069
# 3           0.28390         0.24140              0.10520         0.2597
# 4           0.13280         0.19800              0.10430         0.1809
# 5           0.17000         0.15780              0.08089         0.2087
# 6           0.10900         0.11270              0.07400         0.1794
# 7           0.16450         0.09366              0.05985         0.2196
# 8           0.19320         0.18590              0.09353         0.2350
# 9           0.23960         0.22730              0.08543         0.2030
#
#    mean_fractal_dimension  ...  worst_texture  worst_perimeter  worst_area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
# 5                 0.07613  ...          23.75           103.40       741.6
# 6                 0.05742  ...          27.66           153.20      1606.0
# 7                 0.07451  ...          28.14           110.60       897.0
# 8                 0.07389  ...          30.73           106.20       739.3
# 9                 0.08243  ...          40.68            97.65       711.4
#
#    worst_smoothness  worst_compactness  worst_concavity  worst_concave_points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
# 5            0.1791             0.5249           0.5355                0.1741
# 6            0.1442             0.2576           0.3784                0.1932
# 7            0.1654             0.3682           0.2678                0.1556
# 8            0.1703             0.5401           0.5390                0.2060
# 9            0.1853             1.0580           1.1050                0.2210
#
#    worst_symmetry  worst_fractal_dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
# 5          0.3985                  0.12440       0
# 6          0.3063                  0.08368       0
# 7          0.3196                  0.11510       0
# 8          0.4378                  0.10720       0
# 9          0.4366                  0.20750       0
#
# [10 rows x 31 columns]

# %%
# shuffle the data
orig_df = orig_df.sample(frac = 1.0)

# %%
BATCH_SIZE = 16

sample_df = orig_df.iloc[:BATCH_SIZE]

# %%
# build a dict from the sample_df dataframe

input_dict = {}

for col in sample_df.columns:
    # remove the target column
    if col != 'target':
        values = sample_df[col].values.tolist()
        input_dict[col] = values

# %%
input_dict
# Out:
# {'mean_radius': [25.22,
#   10.48,
#   18.81,
#   12.63,
#   14.34,
#   12.58,
#   10.48,
#   12.72,
#   11.14,
#   19.21,
#   13.74,
#   17.02,
#   14.25,
#   12.68,
#   12.89,
#   14.59],
#  'mean_texture': [24.91,
#   14.98,
#   19.98,
#   20.76,
#   13.47,
#   18.4,
#   19.86,
#   17.67,
#   14.07,
#   18.57,
#   17.91,
#   23.98,
#   21.72,
#   23.84,
#   13.12,
#   22.68],
#  'mean_perimeter': [171.5,
#   67.49,
#   120.9,
#   82.15,
#   92.51,
#   79.83,
#   66.72,
#   80.98,
#   71.24,
#   125.5,
#   88.12,
#   112.8,
#   93.63,
#   82.69,
#   81.89,
#   96.39],
#  'mean_area': [1878.0,
#   333.6,
#   1102.0,
#   480.4,
#   641.2,
#   489.0,
#   337.7,
#   501.3,
#   384.6,
#   1152.0,
#   585.0,
#   899.3,
#   633.0,
#   499.0,
#   515.9,
#   657.1],
#  'mean_smoothness': [0.1063,
#   0.09816,
#   0.08923,
#   0.09933,
#   0.09906,
#   0.08393,
#   0.107,
#   0.07896,
#   0.07274,
#   0.1053,
#   0.07944,
#   0.1197,
#   0.09823,
#   0.1122,
#   0.06955,
#   0.08473],
#  'mean_compactness': [0.2665,
#   0.1013,
#   0.05884,
#   0.1209,
#   0.07624,
#   0.04216,
#   0.05971,
#   0.04522,
#   0.06064,
#   0.1267,
#   0.06376,
#   0.1496,
#   0.1098,
#   0.1262,
#   0.03729,
#   0.133],
#  'mean_concavity': [0.3339,
#   0.06335,
#   0.0802,
#   0.1065,
#   0.05724,
#   0.00186,
#   0.04831,
#   0.01402,
#   0.04505,
#   0.1323,
#   0.02881,
#   0.2417,
#   0.1319,
#   0.1128,
#   0.0226,
#   0.1029],
#  'mean_concave_points': [0.1845,
#   0.02218,
#   0.05843,
#   0.06021,
#   0.04603,
#   0.002924,
#   0.0307,
#   0.01835,
#   0.01471,
#   0.08994,
#   0.01329,
#   0.1203,
#   0.05598,
#   0.06873,
#   0.01171,
#   0.03736],
#  'mean_symmetry': [0.1829,
#   0.1925,
#   0.155,
#   0.1735,
#   0.2075,
#   0.1697,
#   0.1737,
#   0.1459,
#   0.169,
#   0.1917,
#   0.1473,
#   0.2248,
#   0.1885,
#   0.1905,
#   0.1337,
#   0.1454],
#  'mean_fractal_dimension': [0.06782,
#   0.06915,
#   0.04996,
#   0.0707,
#   0.05448,
#   0.05855,
#   0.0644,
#   0.05544,
#   0.06083,
#   0.05961,
#   0.0558,
#   0.06382,
#   0.06125,
#   0.0659,
#   0.05581,
#   0.06147],
#  'radius_error': [0.8973,
#   0.3276,
#   0.3283,
#   0.3424,
#   0.522,
#   0.2719,
#   0.3719,
#   0.2954,
#   0.4222,
#   0.7275,
#   0.25,
#   0.6009,
#   0.286,
#   0.4255,
#   0.1532,
#   0.2254],
#  'texture_error': [1.474,
#   1.127,
#   0.828,
#   1.803,
#   0.8121,
#   1.35,
#   2.612,
#   0.8836,
#   0.8092,
#   1.193,
#   0.7574,
#   1.398,
#   1.019,
#   1.178,
#   0.469,
#   1.108],
#  'perimeter_error': [7.382,
#   2.564,
#   2.363,
#   2.711,
#   3.763,
#   1.721,
#   2.517,
#   2.109,
#   3.33,
#   4.837,
#   1.573,
#   3.999,
#   2.657,
#   2.927,
#   1.115,
#   2.224],
#  'area_error': [120.0,
#   20.77,
#   36.74,
#   20.48,
#   48.29,
#   22.45,
#   23.22,
#   23.24,
#   28.84,
#   102.5,
#   21.47,
#   67.78,
#   24.91,
#   36.46,
#   12.68,
#   19.54],
#  'smoothness_error': [0.008166,
#   0.007364,
#   0.007571,
#   0.01291,
#   0.007089,
#   0.006383,
#   0.01604,
#   0.007337,
#   0.005541,
#   0.006458,
#   0.002838,
#   0.008268,
#   0.005878,
#   0.007781,
#   0.004731,
#   0.004242],
#  'compactness_error': [0.05693,
#   0.03867,
#   0.01114,
#   0.04042,
#   0.01428,
#   0.008008,
#   0.01386,
#   0.01174,
#   0.03387,
#   0.02306,
#   0.01592,
#   0.03082,
#   0.02995,
#   0.02648,
#   0.01345,
#   0.04639],
#  'concavity_error': [0.0573,
#   0.05263,
#   0.02623,
#   0.05101,
#   0.0236,
#   0.00186,
#   0.01865,
#   0.005383,
#   0.04505,
#   0.02945,
#   0.0178,
#   0.05042,
#   0.04815,
#   0.02973,
#   0.01652,
#   0.06578],
#  'concave_points_error': [0.0203,
#   0.01264,
#   0.01463,
#   0.02295,
#   0.01286,
#   0.002924,
#   0.01133,
#   0.005623,
#   0.01471,
#   0.01538,
#   0.005828,
#   0.01112,
#   0.01161,
#   0.0129,
#   0.005905,
#   0.01606],
#  'symmetry_error': [0.01065,
#   0.02161,
#   0.0193,
#   0.02144,
#   0.02266,
#   0.02571,
#   0.03476,
#   0.0194,
#   0.03102,
#   0.01852,
#   0.01329,
#   0.02102,
#   0.02028,
#   0.01635,
#   0.01619,
#   0.01638],
#  'fractal_dimension_error': [0.005893,
#   0.00483,
#   0.001676,
#   0.005891,
#   0.001463,
#   0.002015,
#   0.00356,
#   0.00118,
#   0.004831,
#   0.002608,
#   0.001976,
#   0.003854,
#   0.004022,
#   0.003601,
#   0.002081,
#   0.004406],
#  'worst_radius': [30.0,
#   12.13,
#   19.96,
#   13.33,
#   16.77,
#   13.5,
#   11.48,
#   13.82,
#   12.12,
#   26.14,
#   15.34,
#   20.88,
#   15.89,
#   17.09,
#   13.62,
#   15.48],
#  'worst_texture': [33.62,
#   21.57,
#   24.3,
#   25.47,
#   16.9,
#   23.08,
#   29.46,
#   20.96,
#   15.82,
#   28.14,
#   22.46,
#   32.09,
#   30.36,
#   33.47,
#   15.54,
#   27.27],
#  'worst_perimeter': [211.7,
#   81.41,
#   129.0,
#   89.0,
#   110.4,
#   85.56,
#   73.68,
#   88.87,
#   79.62,
#   170.1,
#   97.19,
#   136.1,
#   116.2,
#   111.8,
#   87.4,
#   105.9],
#  'worst_area': [2562.0,
#   440.4,
#   1236.0,
#   527.4,
#   873.2,
#   564.1,
#   402.8,
#   586.8,
#   453.5,
#   2145.0,
#   725.9,
#   1344.0,
#   799.6,
#   888.3,
#   577.0,
#   733.5],
#  'worst_smoothness': [0.1573,
#   0.1327,
#   0.1243,
#   0.1287,
#   0.1297,
#   0.1038,
#   0.1515,
#   0.1068,
#   0.08864,
#   0.1624,
#   0.09711,
#   0.1634,
#   0.1446,
#   0.1851,
#   0.09616,
#   0.1026],
#  'worst_compactness': [0.6076,
#   0.2996,
#   0.116,
#   0.225,
#   0.1525,
#   0.06624,
#   0.1026,
#   0.09605,
#   0.1256,
#   0.3511,
#   0.1824,
#   0.3559,
#   0.4238,
#   0.4061,
#   0.1147,
#   0.3171],
#  'worst_concavity': [0.6476,
#   0.2939,
#   0.221,
#   0.2216,
#   0.1632,
#   0.005579,
#   0.1181,
#   0.03469,
#   0.1201,
#   0.3879,
#   0.1564,
#   0.5588,
#   0.5186,
#   0.4024,
#   0.1186,
#   0.3662],
#  'worst_concave_points': [0.2867,
#   0.0931,
#   0.1294,
#   0.1105,
#   0.1087,
#   0.008772,
#   0.06736,
#   0.03612,
#   0.03922,
#   0.2091,
#   0.06019,
#   0.1847,
#   0.1447,
#   0.1716,
#   0.05366,
#   0.1105],
#  'worst_symmetry': [0.2355,
#   0.302,
#   0.2567,
#   0.2226,
#   0.3062,
#   0.2505,
#   0.2883,
#   0.2165,
#   0.2576,
#   0.3537,
#   0.235,
#   0.353,
#   0.3591,
#   0.3383,
#   0.2309,
#   0.2258],
#  'worst_fractal_dimension': [0.1051,
#   0.09646,
#   0.05737,
#   0.08486,
#   0.06072,
#   0.06431,
#   0.07748,
#   0.06025,
#   0.07018,
#   0.08294,
#   0.07014,
#   0.08482,
#   0.1014,
#   0.1031,
#   0.06915,
#   0.08004]}

# %%
json.dump(input_dict, open( "sample1.json", 'w' ) )
